# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("IBM_HR_Attrition.csv")

# %%
df.head(10)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
# 5   32        No  Travel_Frequently       1005  Research & Development
# 6   59        No      Travel_Rarely       1324  Research & Development
# 7   30        No      Travel_Rarely       1358  Research & Development
# 8   38        No  Travel_Frequently        216  Research & Development
# 9   36        No      Travel_Rarely       1299  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
duplicate_rows=df[df.duplicated()]
print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, Education, EducationField, EmployeeCount, EmployeeNumber, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, Over18, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StandardHours, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager]
# Index: []
#
# [0 rows x 35 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
check_columns=['Age', 'DailyRate', 'DistanceFromHome', 'HourlyRate', 
    'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 
    'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear', 
    'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 
    'YearsWithCurrManager']

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df[check_columns], orient='h')
plt.title('Boxplot of Numerical Columns')
plt.xlabel('Value')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(data=df['MonthlyIncome'])
plt.title('Monthly Income')
plt.show()

# %%
df['MonthlyIncome'].describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
Q1=df['MonthlyIncome'].quantile(0.25)
Q3=df['MonthlyIncome'].quantile(0.75)
IQR=Q3-Q1

# %%
print(Q1)
print(Q3)
print(IQR)
# Out:
# 2911.0
# 8379.0
# 5468.0

# %%
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR
print(lower_bound)
print(upper_bound)
# Out:
# -5291.0
# 16581.0

# %%
outliers=df[(df['MonthlyIncome']<lower_bound) | (df['MonthlyIncome']>upper_bound)]
print(outliers)
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 25     53        No      Travel_Rarely       1282  Research & Development
# 29     46        No      Travel_Rarely        705                   Sales
# 45     41       Yes      Travel_Rarely       1360  Research & Development
# 62     50        No      Travel_Rarely        989  Research & Development
# 105    59        No         Non-Travel       1420         Human Resources
# ...   ...       ...                ...        ...                     ...
# 1374   58        No      Travel_Rarely        605                   Sales
# 1377   49        No  Travel_Frequently       1064  Research & Development
# 1401   55        No      Travel_Rarely        189         Human Resources
# 1437   39        No         Non-Travel        105  Research & Development
# 1443   42        No      Travel_Rarely        300  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# ...

# %%
df['MonthlyIncome']=df['MonthlyIncome'].clip(lower=lower_bound, upper=upper_bound)

# %%
print(df['MonthlyIncome'].describe())
# Out:
# count     1470.000000
# mean      6361.891837
# std       4353.345470
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      16581.000000
# Name: MonthlyIncome, dtype: float64

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df["Attrition"])
plt.xlabel("Count of Employees")
plt.ylabel("Attrition")
plt.title("Distribution of Attrition")
plt.show()

# %%
employees_Stayed=df[df["Attrition"]=="No"]
employees_Left=df[df["Attrition"]=="Yes"]

# %%
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
plt.hist(employees_stayed['Age'], bins=20, alpha=0.5, label="Stayed")
plt.hist(employees_Left["Age"], bins=20, alpha=0.5, label="Left")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Distribution of Age")
plt.legend()


plt.subplot(1,2,2)
plt.hist(employees_stayed['MonthlyIncome'], bins=20, alpha=0.5, label="Stayed")
plt.hist(employees_Left["MonthlyIncome"], bins=20, alpha=0.5, label="Left")
plt.xlabel("Monthly Income")
plt.ylabel("Frequency")
plt.title("Distribution of Monthly Income")
plt.legend()

# %%
categorical_Features=["JobRole", "EducationField", "MaritalStatus"]

# %%
for feature in categorical_features:
    plt.figure(figsize=(10,6))

    stayed_counts=employees_stayed[feature].value_counts()
    left_counts=employees_left[feature].value_counts()

    all_categories= set(stayed_counts.index).union(set(left_counts.index))

    x=range(len(all_categories))

    plt.bar(x,stayed_counts, width=width, label="Stayed")
    plt.bar([i+width for i in x], left_counts, width=width, label="Left")

    plt.xlabel(feature)
    plt.ylabel("Frequency")
    plt.title(f'{feature} Distribution')
    plt.xticks([i + width/2 for i in x], all_categories, rotation=90)
    plt.legend()
